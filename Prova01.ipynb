# %% [markdown]
# #Atividade Controle de Entrada de Cinema

# %%
idade = float(input("Insira sua idade: "))

while true:
    
    if idade < 16:
        print("Entrada permitida apenas com acompanhante.")
       
    else:
        valor = float(input("Quanto de dinheiro possui na carteira? R$ "))
        
        if valor >= 30:
            print("Ingresso comprado! Bom filme!")
        else:
            print("Saldo insuficiente para o ingresso.")
            break

proximo = input("Deseja verificar outro cliente (S/N)? ").upper()
if proximo = ("S"):
     if proximo != 'S':
        print("Programa acabou.")
        break
# Out:
#   Cell In[33], line 18
#     if proximo = ("S"):
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
